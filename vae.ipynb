# %%
import keras
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Input, LSTM, RepeatVector
from keras.layers.core import Flatten, Dense, Dropout, Lambda
from keras.optimizers import SGD, RMSprop, Adam
from keras import objectives
from keras.preprocessing import sequence

def create_lstm_vae(input_dim, timesteps, batch_size, intermediate_dim, latent_dim,epsilon_std=1.):

    x = Input(shape=(timesteps, input_dim))

    # LSTM encoding
    h = LSTM(intermediate_dim)(x)

    # VAE Z layer
    z_mean = Dense(latent_dim)(h)
    z_log_sigma = Dense(latent_dim)(h)
    
    def sampling(args):
        z_mean, z_log_sigma = args
        epsilon = K.random_normal(shape=(batch_size, latent_dim),
                                  mean=0., stddev=epsilon_std)
        return z_mean + z_log_sigma * epsilon

    # note that "output_shape" isn't necessary with the TensorFlow backend
    # so you could write `Lambda(sampling)([z_mean, z_log_sigma])`
    z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_sigma])
    
    # decoded LSTM layer
    decoder_h = LSTM(intermediate_dim, return_sequences=True)
    decoder_mean = LSTM(input_dim, return_sequences=True)

    h_decoded = RepeatVector(timesteps)(z)
    h_decoded = decoder_h(h_decoded)

    # decoded layer
    x_decoded_mean = decoder_mean(h_decoded)
    
    # end-to-end autoencoder
    vae = Model(x, x_decoded_mean)

    # encoder, from inputs to latent space
    encoder = Model(x, z_mean)

    # generator, from latent space to reconstructed inputs
    decoder_input = Input(shape=(latent_dim,))

    _h_decoded = RepeatVector(timesteps)(decoder_input)
    _h_decoded = decoder_h(_h_decoded)

    _x_decoded_mean = decoder_mean(_h_decoded)
    generator = Model(decoder_input, _x_decoded_mean)
    
    def vae_loss(x, x_decoded_mean):
        xent_loss = objectives.mse(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma))
        loss = xent_loss + kl_loss
        return loss

    vae.compile(optimizer='adam', loss=vae_loss)
    
    return vae, encoder, generator

# %%
import glob
import numpy as np
from sklearn.model_selection import train_test_split
dir = './sequence/*'
# file read
all_data = []
sequence_length = []
for file in sorted(glob.glob(dir)):
    datasets = []
    for f in open(file, 'r'):
        f = f.replace(']', '').replace('[', '').replace('\n','')
        (u, v, w) = f.split(',')
        datasets.append([int(u), int(v), float(w)])
    sequence_length.append(len(datasets))
    all_data.append(datasets)
#all_data = np.array(all_data)
all_data = np.array([np.array(arr) for arr in all_data])

# %%
# timesteps 맞춰주기 위해서 padding 추가
max_sequence_length = max(sequence_length)
all_data = sequence.pad_sequences(all_data, padding='post', maxlen = max_sequence_length)

# %%
x_train, x_test = train_test_split(all_data, test_size = 0.2)
x_test, x_val = train_test_split(x_test, test_size = 0.66)

# %%
vae, enc, gen = create_lstm_vae(3, 
        timesteps=max_sequence_length, 
        batch_size=1, 
        intermediate_dim=32,
        latent_dim=128,
        epsilon_std=1.)

# %%
vae.fit(x_train, x_train, epochs=1000, batch_size=25,  validation_data=(x_val, x_val))
# Out:
# Train on 540 samples, validate on 90 samples
# Epoch 1/1000
# 540/540 [==============================] - 2s 4ms/step - loss: 13.5286 - val_loss: 12.6100
# Epoch 2/1000
# 540/540 [==============================] - 1s 1ms/step - loss:
1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7253
# Epoch 182/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7254
# Epoch 183/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7255
# Epoch 184/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7253
# Epoch 185/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7254
# Epoch 186/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6750 - val_loss: 10.7255
# Epoch 187/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6750 - val_loss: 10.7254
# Epoch 188/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7254
# Epoch 189/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7253
# Epoch 190/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7259
# Epoch 191/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6754 - val_loss: 10.7254
# Epoch 192/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6752 - val_loss: 10.7256
# Epoch 193/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7262
# Epoch 194/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6748 - val_loss: 10.7252
# Epoch 195/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6748 - val_loss: 10.7252
# Epoch 196/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7251
# Epoch 197/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7252
# Epoch 198/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6748 - val_loss: 10.7251
# Epoch 199/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7252
# Epoch 200/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7251
# Epoch 201/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7251
# Epoch 202/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7252
# Epoch 203/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7251
# Epoch 204/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7250
# Epoch 205/1000
# 540/540 [==============================] - 1s 2ms/step - loss: 10.6746 - val_loss: 10.7253
# Epoch 206/1000
# 540/540 [==============================] - 1s 2ms/step - loss: 10.6746 - val_loss: 10.7250
# Epoch 207/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7250
# Epoch 208/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7251
# Epoch 209/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7250
# Epoch 210/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7251
# Epoch 211/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7250
# Epoch 212/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7249
# Epoch 213/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7249
# Epoch 214/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7250
# Epoch 215/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7251
# Epoch 216/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 217/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7252
# Epoch 218/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7252
# Epoch 219/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 220/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 221/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7250
# Epoch 222/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7249
# Epoch 223/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7251
# Epoch 224/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 225/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7250
# Epoch 226/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6749 - val_loss: 10.7255
# Epoch 227/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7250
# Epoch 228/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 229/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6748 - val_loss: 10.7252
# Epoch 230/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6746 - val_loss: 10.7250
# Epoch 231/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 232/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7249
# Epoch 233/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 234/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 235/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 236/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7249
# Epoch 237/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 238/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 239/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 240/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 241/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 242/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 243/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7248
# Epoch 244/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 245/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7248
# Epoch 246/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 247/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 248/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 249/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 250/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 251/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 252/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 253/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7246
# Epoch 254/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7247
# Epoch 255/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6743 - val_loss: 10.7246
# Epoch 256/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6742 - val_loss: 10.7246
# Epoch 257/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6742 - val_loss: 10.7247
# Epoch 258/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6742 - val_loss: 10.7247
# Epoch 259/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6742 - val_loss: 10.7247
# Epoch 260/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6742 - val_loss: 10.7247
# Epoch 261/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6742 - val_loss: 10.7246
# Epoch 262/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6742 - val_loss: 10.7246
# Epoch 263/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 264/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7247
# Epoch 265/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6745 - val_loss: 10.7249
# Epoch 266/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 267/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7248
# Epoch 268/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6744 - val_loss: 10.7249
# Epoch 269/1000
# 540/540 [==============================] - 1s 1ms/step - loss: 10.6747 - val_loss: 10.7251
# Epoch 270/1000
# 225/540 [===========>..................] - ETA: 0s - loss: 10.1150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2151d5eb0768> in <module>
# ----> 1 vae.fit(x_train, x_train, epochs=1000, batch_size=25,  validation_data=(x_val, x_val))
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# ~/anaconda3/envs/graph/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
