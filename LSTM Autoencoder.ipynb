# %%
import numpy as np
import glob, os
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
dir = './sequence/*'

# %%
# file read
all_data = []
sequence_length = []
for file in sorted(glob.glob(dir)):
    datasets = []
    for f in open(file, 'r'):
        f = f.replace(']', '').replace('[', '').replace('\n','')
        (u, v, w) = f.split(',')
        datasets.append([int(u), int(v), float(w)])
    sequence_length.append(len(datasets))
    all_data.append(datasets)
#all_data = np.array(all_data)
all_data = np.array([np.array(arr) for arr in all_data])

# %%
x_train, x_test = train_test_split(all_data, test_size = 0.2)
x_test, x_val = train_test_split(x_test, test_size = 0.66)

# %%
max_sequence_length = max(sequence_length)
n_features = 3
batch_size = 32
epochs = 100

# %%
# timesteps 맞춰주기 위해서 padding 추가
#all_data = sequence.pad_sequences(all_data, padding='post', maxlen = max_sequence_length)

# %%
model = Sequential()
model.add(LSTM(128, activation='relu', input_shape=(None, n_features), return_sequences=True))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(n_features, return_sequences=True))
#model.add(Dense(1))
#model.add(LSTM(n_features, return_sequences=True))
#model.add(LSTM(10, return_sequences=True))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0913 19:33:13.111018 139673696331520 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0913 19:33:13.124020 139673696331520 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0913 19:33:13.125261 139673696331520 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# W0913 19:33:14.592322 139673696331520 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
import random as rd
def train_generator(x_train):
    idx = 0
    while True:
        yield np.array([x_train[idx]]), np.array([x_train[idx]])
        idx +=1
        if idx >= len(x_train):
            idx = 0
model.fit_generator(train_generator(x_train), epochs=epochs, steps_per_epoch=540, verbose=1)#, validation_data=(x_val, x_val))
# Out:
# W0913 19:33:17.568226 139673696331520 deprecation.py:323] From /home/minji/anaconda3/envs/graph/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0913 19:33:18.473307 139673696331520 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0913 19:33:18.543152 139673696331520 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/1000
# 540/540 [==============================] - 9s 17ms/step - loss: 17.0069
# Epoch 2/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4708
# Epoch 3/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 4/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 5/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 6/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 7/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 8/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 9/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 10/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 11/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 12/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 13/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 14/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 15/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 16/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 17/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 18/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 19/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 20/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 21/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 22/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 23/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 24/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 25/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 26/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 27/1000
# 540/540 [==============================] - 8s 16ms/step - loss: 16.4705
# Epoch 28/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 29/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 30/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 31/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 32/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 33/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 34/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 35/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 36/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 37/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 38/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 39/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 40/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 41/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 42/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 43/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 44/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 45/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 46/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 47/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 48/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 49/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 50/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 51/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 52/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 53/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 54/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 55/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 56/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 57/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 58/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 59/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 60/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 61/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 62/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 63/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 64/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 65/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 66/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 67/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 68/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 69/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 70/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 71/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 72/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 73/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 74/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 75/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 76/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 77/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 78/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 79/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 80/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 81/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 82/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 83/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 84/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 85/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 86/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 87/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 88/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 89/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 90/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 91/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 92/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 93/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 94/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 95/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 96/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 97/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 98/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 99/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 100/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 101/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 102/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 103/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 104/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 105/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 106/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 107/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 108/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 109/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 110/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 111/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 112/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 113/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 114/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 115/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 116/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 117/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 118/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 119/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 120/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 121/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 122/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 123/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 124/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 125/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 126/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 127/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 128/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 129/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 130/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 131/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 132/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 133/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 134/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 135/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 136/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 137/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 138/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 139/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 140/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 141/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 142/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 143/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 144/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 145/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 146/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 147/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 148/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 149/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 150/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 151/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 152/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 153/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 154/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 155/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 156/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 157/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 158/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 159/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 160/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 161/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 162/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 163/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 164/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 165/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 166/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 167/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 168/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 169/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 170/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 171/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 172/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 173/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 174/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 175/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 176/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 177/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 178/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 179/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 180/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 181/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 182/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 183/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 184/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 185/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 186/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 187/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 188/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 189/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 190/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 191/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 192/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 193/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 194/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 195/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 196/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 197/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 198/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 199/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 200/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 201/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 202/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 203/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 204/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 205/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 206/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 207/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 208/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 209/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 210/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 211/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 212/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 213/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 214/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 215/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 216/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 217/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 218/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 219/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 220/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 221/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 222/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 223/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 224/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 225/1000
# 540/540 [==============================] - 8s 14ms/step - loss: 16.4705
# Epoch 226/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 227/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 228/1000
# 540/540 [==============================] - 8s 15ms/step - loss: 16.4705
# Epoch 229/1000
#  97/540 [====>.........................] - ETA: 7s - loss: 16.8508
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b32506622a29> in <module>
#       7         if idx >= len(x_train):
#       8             idx = 0
# ----> 9 model.fit_generator(train_generator(x_train), epochs=epochs, steps_per_epoch=540, verbose=1)#, validation_data=(x_val, x_val))
#
# ~/.local/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1656             use_multiprocessing=use_multiprocessing,
#    1657             shuffle=shuffle,
# -> 1658             initial_epoch=initial_epoch)
#    1659
#    1660     @interfaces.legacy_generator_methods_support
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     213                 outs = model.train_on_batch(x, y,
#     214                                             sample_weight=sample_weight,
# --> 215                                             class_weight=class_weight)
#     216
#     217                 outs = to_list(outs)
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1447             ins = x + y + sample_weights
#    1448         self._make_train_function()
# -> 1449         outputs = self.train_function(ins)
#    1450         return unpack_singleton(outputs)
#    1451
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# ~/anaconda3/envs/graph/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
x_train, x_test = train_test_split(all_data, test_size = 0.2)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, None, 32)          4608
# _________________________________________________________________
# lstm_4 (LSTM)                (None, None, 3)           432
# =================================================================
# Total params: 5,040
# Trainable params: 5,040
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,x_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, x_test))
# Out:
# W0913 18:10:41.008506 140372623795968 deprecation.py:323] From /home/minji/anaconda3/envs/graph/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0913 18:10:41.588486 140372623795968 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0913 18:10:41.636524 140372623795968 deprecation_wrapper.py:119] From /home/minji/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 540 samples, validate on 135 samples
# Epoch 1/1000
# 540/540 [==============================] - 1s 2ms/step - loss: 12.3111 - val_loss: 11.1024
# Epoch 2/1000
# 540/540 [==============================] - 0s 597us/step - loss: 11.4116 - val_loss: 10.3088
# Epoch 3/1000
# 540/540 [==============================] - 0s 591us/step - loss: 10.9557 - val_loss: 10.1261
# Epoch 4/1000
# 540/540 [==============================] - 0s 624us/step - loss: 10.8217 - val_loss: 10.0111
# Epoch 5/1000
# 540/540 [==============================] - 0s 624us/step - loss: 10.7187 - val_loss: 9.9477
# Epoch 6/1000
# 540/540 [==============================] - 0s 602us/step - loss: 10.6615 - val_loss: 9.8978
# Epoch 7/1000
# 540/540 [==============================] - 0s 610us/step - loss: 10.6191 - val_loss: 9.8708
# Epoch 8/1000
# 540/540 [==============================] - 0s 646us/step - loss: 10.5837 - val_loss: 9.8273
# Epoch 9/1000
# 540/540 [==============================] - 0s 630us/step - loss: 10.5509 - val_loss: 9.7931
# Epoch 10/1000
# 540/540 [==============================] - 0s 644us/step - loss: 10.5231 - val_loss: 9.7705
# Epoch 11/1000
# 540/540 [==============================] - 0s 645us/step - loss: 10.5058 - val_loss: 9.7604
# Epoch 12/1000
# 540/540 [==============================] - 0s 612us/step - loss: 10.4892 - val_loss: 9.7449
# Epoch 13/1000
# 540/540 [==============================] - 0s 607us/step - loss: 10.4765 - val_loss: 9.7346
# Epoch 14/1000
# 540/540 [==============================] - 0s 633us/step - loss: 10.4673 - val_loss: 9.7270
# Epoch 15/1000
# 128/540 [======>.......................] - ETA: 0s - loss: 10.4120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-950f92f6c3e4> in <module>
# ----> 1 model.fit(x_train,x_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, x_test))
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# ~/anaconda3/envs/graph/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
